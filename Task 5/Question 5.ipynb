# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
titanic = sns.load_dataset( "titanic" )
df = pd.DataFrame( titanic )

# %%
df.head(11)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
dk = df.drop( columns = ["who", "deck", "adult_male", 'sex', "fare", "alive", "embark_town"] )
dk
# Out:
#      survived  pclass   age  sibsp  parch embarked   class  alone
# 0           0       3  22.0      1      0        S   Third  False
# 1           1       1  38.0      1      0        C   First  False
# 2           1       3  26.0      0      0        S   Third   True
# 3           1       1  35.0      1      0        S   First  False
# 4           0       3  35.0      0      0        S   Third   True
# ..        ...     ...   ...    ...    ...      ...     ...    ...
# 886         0       2  27.0      0      0        S  Second   True
# 887         1       1  19.0      0      0        S   First   True
# 888         0       3   NaN      1      2        S   Third  False
# 889         1       1  26.0      0      0        C   First   True
# 890         0       3  32.0      0      0        Q   Third   True
#
# [891 rows x 8 columns]

# %%
df["class"].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
classno = {
    "Third" : 3 ,
    "Second" : 2 ,
    "First" : 1 ,
}

# %%
dk["class"] = dk["class"].map( classno )
dk
# Out:
#      survived  pclass   age  sibsp  parch embarked class  alone
# 0           0       3  22.0      1      0        S     3  False
# 1           1       1  38.0      1      0        C     1  False
# 2           1       3  26.0      0      0        S     3   True
# 3           1       1  35.0      1      0        S     1  False
# 4           0       3  35.0      0      0        S     3   True
# ..        ...     ...   ...    ...    ...      ...   ...    ...
# 886         0       2  27.0      0      0        S     2   True
# 887         1       1  19.0      0      0        S     1   True
# 888         0       3   NaN      1      2        S     3  False
# 889         1       1  26.0      0      0        C     1   True
# 890         0       3  32.0      0      0        Q     3   True
#
# [891 rows x 8 columns]

# %%
dk["age"].fillna( 0 )
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
dk["embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
dk["embarked"] = dk["embarked"].fillna( value='S' )

# %%
dk["embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
dk["embarked"] = dk["embarked"].map( {
    'S' : 1 ,
    'C' : 2 ,
    'Q' : 3 
} )

# %%
dk
# Out:
#      survived  pclass   age  sibsp  parch  embarked class  alone
# 0           0       3  22.0      1      0         1     3  False
# 1           1       1  38.0      1      0         2     1  False
# 2           1       3  26.0      0      0         1     3   True
# 3           1       1  35.0      1      0         1     1  False
# 4           0       3  35.0      0      0         1     3   True
# ..        ...     ...   ...    ...    ...       ...   ...    ...
# 886         0       2  27.0      0      0         1     2   True
# 887         1       1  19.0      0      0         1     1   True
# 888         0       3   NaN      1      2         1     3  False
# 889         1       1  26.0      0      0         2     1   True
# 890         0       3  32.0      0      0         3     3   True
#
# [891 rows x 8 columns]

# %%
sns.countplot( dk.survived )
# Out:
# c:\Users\straw\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.countplot( dk.embarked )
# Out:
# c:\Users\straw\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='embarked', ylabel='count'>
