# %%
import numpy as np
import pandas as pd

# %%
# READING CSV AND SAVING IT AS A PANDAS DATAFRAME
df = pd.read_csv( "./Assets/Q4-Dataset.csv" )
print(df)
# Out:
#      ProductID  price  rating
# 0   B001E4KFG0    140    3.43
# 1   B00813GRG4    183    3.91
# 2   B000LQOCH0    160    4.60
# 3   B000UA0QIQ    161    3.64
# 4   B006K2ZZ7K    157    1.76
# ..         ...    ...     ...
# 94  B001FB69YY     98    2.24
# 95  B004OYBN7C     81    1.29
# 96  B000JEHAHS    133    0.12
# 97  B003VTN95K    197    1.84
# 98  B007DJ0O9I     94    4.31
#
# [99 rows x 3 columns]

# %%
# MAKING THE DATAFRAME TO A NUMPY ARRAY
np_array = np.array( df )
print(np_array)
# Out:
# array([['B001E4KFG0', 140, 3.43],
#        ['B00813GRG4', 183, 3.91],
#        ['B000LQOCH0', 160, 4.6],
#        ['B000UA0QIQ', 161, 3.64],
#        ['B006K2ZZ7K', 157, 1.76],
#        ['B000E7L2R4', 148, 0.48],
#        ['B00171APVA', 184, 1.0],
#        ['B0001PB9FE', 148, 0.29],
#        ['B0009XLVG0', 116, 2.36],
#        ['B001GVISJM', 177, 0.61],
#        ['B00144C10S', 182, 1.86],
#        ['B0001PB9FY', 183, 0.19],
#        ['B003F6UO7K', 141, 2.7],
#        ['B001EO5QW8', 165, 3.74],
#        ['B000G6RPMY', 111, 0.38],
#        ['B002GWHC0G', 165, 0.26],
#        ['B004N5KULM', 166, 3.23],
#        ['B001EO5TPM', 161, 2.11],
#        ['B005DUM9UQ', 138, 0.24],
#        ['B000E7VI7S', 103, 1.99],
#        ['B001GVISJC', 81, 2.47],
#        ['B006SQBRMA', 188, 3.97],
#        ['B0059WXJKM', 148, 3.73],
#        ['B001EPPI84', 184, 4.21],
#        ['B004X2KR36', 126, 2.74],
#        ['B005R8JE8O', 83, 4.34],
#        ['B0066DMI6Y', 148, 1.9],
#        ['B003ZFRKGO', 191, 1.59],
#        ['B0019CW0HE', 178, 0.43],
#        ['B004K2IHUO', 175, 2.82],
#        ['B001REEG6C', 100, 2.44],
#        ['B000J0HIT2', 180, 2.7],
#        ['B0037LW78C', 195, 4.55],
#        ['B0026Y3YBK', 180, 3.26],
#        ['B003SE19UK', 160, 3.48],
#        ['B003OB0IB8', 133, 4.08],
#        ['B002SRYRE8', 189, 4.67],
#        ['B001GVISJW', 144, 2.05],
#        ['B0017I8UME', 139, 0.43],
#        ['B0064KU9HO', 159, 1.15],
#        ['B0037ZFEW4', 117, 4.85],
#        ['B00374XSVY', 120, 4.7],
#        ['B005P0HHGK', 170, 0.1],
#        ['B002HQAXUW', 165, 3.68],
#        ['B000SV90J8', 118, 3.22],
#        ['B0036VM05I', 174, 1.72],
#        ['B000ITVLE2', 126, 0.84],
#        ['B003TQQKFQ', 113, 4.55],
#        ['B007B9J6G2', 80, 4.18],
#        ['B0064KO0BU', 157, 0.74],
#        ['B001IUKD76', 89, 4.58],
#        ['B0081XN2HQ', 129, 3.51],
#        ['B0025VRCJY', 153, 3.91],
#        ['B005CJVVJ8', 108, 4.05],
#        ['B001KUUNP6', 178, 0.74],
#        ['B000NY8ODS', 162, 1.08],
#        ['B00029XIZI', 81, 2.59],
#        ['B004V6AH34', 103, 4.24],
#        ['B0028C44Z0', 151, 2.22],
#        ['B0009XLVGA', 195, 2.11],
#        ['B002TDK0VK', 196, 4.8],
#        ['B0040WAG7Q', 90, 2.2],
#        ['B001EO5ZMO', 178, 1.04],
#        ['B001SATU8E', 166, 1.91],
#        ['B007JFV6RK', 197, 2.89],
#        ['B001L4ELRW', 108, 1.53],
#        ['B003SO503C', 162, 0.6],
#        ['B003ZFXJDW', 110, 4.11],
#        ['B001HTL6CY', 160, 4.26],
#        ['B000WFRMRW', 174, 1.13],
#        ['B001EO5ZME', 156, 0.64],
#        ['B0093NIWVO', 127, 0.31],
#        ['B001EO5ZMY', 114, 2.66],
#        ['B007TFONH0', 152, 2.15],
#        ['B000GGKQSO', 185, 0.83],
#        ['B007J32WX4', 104, 2.29],
#        ['B0017129DC', 159, 0.45],
#        ['B0002567IW', 163, 3.53],
#        ['B0048IC328', 88, 2.29],
#        ['B0025WIAN0', 82, 0.77],
#        ['B00821UN4M', 153, 3.47],
#        ['B00473RWXY', 150, 3.48],
#        ['B002MV23XM', 148, 1.89],
#        ['B000LKZK7C', 194, 0.88],
#        ['B001D07IPG', 197, 3.93],
#        ['B000H13270', 80, 3.52],
#        ['B001UJEN6C', 99, 4.63],
#        ['B003EMU7EU', 114, 4.56],
#        ['B0064KOUNI', 152, 3.98],
#        ['B003YDP5PA', 169, 4.98],
#        ['B002X9JNYU', 171, 2.61],
#        ['B001EPQ0J0', 150, 3.09],
#        ['B000O9Y62A', 97, 4.59],
#        ['B00283TPYE', 100, 2.94],
#        ['B001FB69YY', 98, 2.24],
#        ['B004OYBN7C', 81, 1.29],
#        ['B000JEHAHS', 133, 0.12],
#        ['B003VTN95K', 197, 1.84],
#        ['B007DJ0O9I', 94, 4.31]], dtype=object)

# %%
# SORTING NUMPY ARRAY ACCORDING TO RATING 
np_array.sort( axis = 0 )
print(np_array)
# Out:
# [['B0001PB9FE' 80 0.1]
#  ['B0001PB9FY' 80 0.12]
#  ['B0002567IW' 81 0.19]
#  ['B00029XIZI' 81 0.24]
#  ['B0009XLVG0' 81 0.26]
#  ['B0009XLVGA' 82 0.29]
#  ['B000E7L2R4' 83 0.31]
#  ['B000E7VI7S' 88 0.38]
#  ['B000G6RPMY' 89 0.43]
#  ['B000GGKQSO' 90 0.43]
#  ['B000H13270' 94 0.45]
#  ['B000ITVLE2' 97 0.48]
#  ['B000J0HIT2' 98 0.6]
#  ['B000JEHAHS' 99 0.61]
#  ['B000LKZK7C' 100 0.64]
#  ['B000LQOCH0' 100 0.74]
#  ['B000NY8ODS' 103 0.74]
#  ['B000O9Y62A' 103 0.77]
#  ['B000SV90J8' 104 0.83]
#  ['B000UA0QIQ' 108 0.84]
#  ['B000WFRMRW' 108 0.88]
#  ['B00144C10S' 110 1.0]
#  ['B0017129DC' 111 1.04]
#  ['B00171APVA' 113 1.08]
#  ['B0017I8UME' 114 1.13]
#  ['B0019CW0HE' 114 1.15]
#  ['B001D07IPG' 116 1.29]
#  ['B001E4KFG0' 117 1.53]
#  ['B001EO5QW8' 118 1.59]
#  ['B001EO5TPM' 120 1.72]
#  ['B001EO5ZME' 126 1.76]
#  ['B001EO5ZMO' 126 1.84]
#  ['B001EO5ZMY' 127 1.86]
#  ['B001EPPI84' 129 1.89]
#  ['B001EPQ0J0' 133 1.9]
#  ['B001FB69YY' 133 1.91]
#  ['B001GVISJC' 138 1.99]
#  ['B001GVISJM' 139 2.05]
#  ['B001GVISJW' 140 2.11]
#  ['B001HTL6CY' 141 2.11]
#  ['B001IUKD76' 144 2.15]
#  ['B001KUUNP6' 148 2.2]
#  ['B001L4ELRW' 148 2.22]
#  ['B001REEG6C' 148 2.24]
#  ['B001SATU8E' 148 2.29]
#  ['B001UJEN6C' 148 2.29]
#  ['B0025VRCJY' 150 2.36]
#  ['B0025WIAN0' 150 2.44]
#  ['B0026Y3YBK' 151 2.47]
#  ['B00283TPYE' 152 2.59]
#  ['B0028C44Z0' 152 2.61]
#  ['B002GWHC0G' 153 2.66]
#  ['B002HQAXUW' 153 2.7]
#  ['B002MV23XM' 156 2.7]
#  ['B002SRYRE8' 157 2.74]
#  ['B002TDK0VK' 157 2.82]
#  ['B002X9JNYU' 159 2.89]
#  ['B0036VM05I' 159 2.94]
#  ['B00374XSVY' 160 3.09]
#  ['B0037LW78C' 160 3.22]
#  ['B0037ZFEW4' 160 3.23]
#  ['B003EMU7EU' 161 3.26]
#  ['B003F6UO7K' 161 3.43]
#  ['B003OB0IB8' 162 3.47]
#  ['B003SE19UK' 162 3.48]
#  ['B003SO503C' 163 3.48]
#  ['B003TQQKFQ' 165 3.51]
#  ['B003VTN95K' 165 3.52]
#  ['B003YDP5PA' 165 3.53]
#  ['B003ZFRKGO' 166 3.64]
#  ['B003ZFXJDW' 166 3.68]
#  ['B0040WAG7Q' 169 3.73]
#  ['B00473RWXY' 170 3.74]
#  ['B0048IC328' 171 3.91]
#  ['B004K2IHUO' 174 3.91]
#  ['B004N5KULM' 174 3.93]
#  ['B004OYBN7C' 175 3.97]
#  ['B004V6AH34' 177 3.98]
#  ['B004X2KR36' 178 4.05]
#  ['B0059WXJKM' 178 4.08]
#  ['B005CJVVJ8' 178 4.11]
#  ['B005DUM9UQ' 180 4.18]
#  ['B005P0HHGK' 180 4.21]
#  ['B005R8JE8O' 182 4.24]
#  ['B0064KO0BU' 183 4.26]
#  ['B0064KOUNI' 183 4.31]
#  ['B0064KU9HO' 184 4.34]
#  ['B0066DMI6Y' 184 4.55]
#  ['B006K2ZZ7K' 185 4.55]
#  ['B006SQBRMA' 188 4.56]
#  ['B007B9J6G2' 189 4.58]
#  ['B007DJ0O9I' 191 4.59]
#  ['B007J32WX4' 194 4.6]
#  ['B007JFV6RK' 195 4.63]
#  ['B007TFONH0' 195 4.67]
#  ['B00813GRG4' 196 4.7]
#  ['B0081XN2HQ' 197 4.8]
#  ['B00821UN4M' 197 4.85]
#  ['B0093NIWVO' 197 4.98]]
