# %%
import numpy as np
import pandas as pd

# %%
# READING CSV AND SAVING IT AS A PANDAS DATAFRAME
df = pd.read_csv( "./Assets/Q4-Dataset.csv" )
print(df)
# Out:
#      ProductID  price  rating
# 0   B001E4KFG0    140    3.43
# 1   B00813GRG4    183    3.91
# 2   B000LQOCH0    160    4.60
# 3   B000UA0QIQ    161    3.64
# 4   B006K2ZZ7K    157    1.76
# ..         ...    ...     ...
# 94  B001FB69YY     98    2.24
# 95  B004OYBN7C     81    1.29
# 96  B000JEHAHS    133    0.12
# 97  B003VTN95K    197    1.84
# 98  B007DJ0O9I     94    4.31
#
# [99 rows x 3 columns]

# %%
# MAKING THE DATAFRAME TO A NUMPY ARRAY
np_array = np.array( df )
print(np_array)
# Out:
# [['B001E4KFG0' 140 3.43]
#  ['B00813GRG4' 183 3.91]
#  ['B000LQOCH0' 160 4.6]
#  ['B000UA0QIQ' 161 3.64]
#  ['B006K2ZZ7K' 157 1.76]
#  ['B000E7L2R4' 148 0.48]
#  ['B00171APVA' 184 1.0]
#  ['B0001PB9FE' 148 0.29]
#  ['B0009XLVG0' 116 2.36]
#  ['B001GVISJM' 177 0.61]
#  ['B00144C10S' 182 1.86]
#  ['B0001PB9FY' 183 0.19]
#  ['B003F6UO7K' 141 2.7]
#  ['B001EO5QW8' 165 3.74]
#  ['B000G6RPMY' 111 0.38]
#  ['B002GWHC0G' 165 0.26]
#  ['B004N5KULM' 166 3.23]
#  ['B001EO5TPM' 161 2.11]
#  ['B005DUM9UQ' 138 0.24]
#  ['B000E7VI7S' 103 1.99]
#  ['B001GVISJC' 81 2.47]
#  ['B006SQBRMA' 188 3.97]
#  ['B0059WXJKM' 148 3.73]
#  ['B001EPPI84' 184 4.21]
#  ['B004X2KR36' 126 2.74]
#  ['B005R8JE8O' 83 4.34]
#  ['B0066DMI6Y' 148 1.9]
#  ['B003ZFRKGO' 191 1.59]
#  ['B0019CW0HE' 178 0.43]
#  ['B004K2IHUO' 175 2.82]
#  ['B001REEG6C' 100 2.44]
#  ['B000J0HIT2' 180 2.7]
#  ['B0037LW78C' 195 4.55]
#  ['B0026Y3YBK' 180 3.26]
#  ['B003SE19UK' 160 3.48]
#  ['B003OB0IB8' 133 4.08]
#  ['B002SRYRE8' 189 4.67]
# ...

# %%
# SORTING NUMPY ARRAY ACCORDING TO RATING 

"""
array.argsort() returns the sorted indices which we then substitute to the elements of the original array
"""
np_array[np_array[ : , 2 ].argsort()]
# Out:
# array([['B005P0HHGK', 170, 0.1],
#        ['B000JEHAHS', 133, 0.12],
#        ['B0001PB9FY', 183, 0.19],
#        ['B005DUM9UQ', 138, 0.24],
#        ['B002GWHC0G', 165, 0.26],
#        ['B0001PB9FE', 148, 0.29],
#        ['B0093NIWVO', 127, 0.31],
#        ['B000G6RPMY', 111, 0.38],
#        ['B0017I8UME', 139, 0.43],
#        ['B0019CW0HE', 178, 0.43],
#        ['B0017129DC', 159, 0.45],
#        ['B000E7L2R4', 148, 0.48],
#        ['B003SO503C', 162, 0.6],
#        ['B001GVISJM', 177, 0.61],
#        ['B001EO5ZME', 156, 0.64],
#        ['B0064KO0BU', 157, 0.74],
#        ['B001KUUNP6', 178, 0.74],
#        ['B0025WIAN0', 82, 0.77],
#        ['B000GGKQSO', 185, 0.83],
#        ['B000ITVLE2', 126, 0.84],
#        ['B000LKZK7C', 194, 0.88],
#        ['B00171APVA', 184, 1.0],
#        ['B001EO5ZMO', 178, 1.04],
#        ['B000NY8ODS', 162, 1.08],
#        ['B000WFRMRW', 174, 1.13],
#        ['B0064KU9HO', 159, 1.15],
#        ['B004OYBN7C', 81, 1.29],
# ...
